# %%
import os
import re
import torch
from torch import nn
from d2l import torch as d2l
#@save
# d2l.DATA_HUB['SNLI'] = (
# 'https://nlp.stanford.edu/projects/snli/snli_1.0.zip',
# '9fcde07509c7e87ec61c640c1b2753d9041758e4')
data_dir = 'D:/data/snli_1.0/snli_1.0'

# %%
def read_snli(data_dir, is_train):
    """将SNLI数据集解析为前提、假设和标签"""
    def extract_text(s):
        # 删除我们不会使用的信息
        s = re.sub('\\(', '', s)
        s = re.sub('\\)', '', s)
        # 用一个空格替换两个或多个连续的空格
        s = re.sub('\\s{2,}', ' ', s)
        return s.strip()
    label_set = {'entailment': 0, 'contradiction': 1, 'neutral': 2}
    file_name = os.path.join(data_dir, 'snli_1.0_train.txt'
    if is_train else 'snli_1.0_test.txt')
    with open(file_name, 'r') as f:
        rows = [row.split('\t') for row in f.readlines()[1:]]
    premises = [extract_text(row[1]) for row in rows if row[0] in label_set]
    hypotheses = [extract_text(row[2]) for row in rows if row[0] \
                in label_set]
    labels = [label_set[row[0]] for row in rows if row[0] in label_set]
    return premises, hypotheses, labels

train_data = read_snli(data_dir, is_train=True)
for x0, x1, y in zip(train_data[0][:3], train_data[1][:3], train_data[2][:3]):
    print('前提：', x0)
    print('假设：', x1)
    print('标签：', y)
# Out:
# 前提： A person on a horse jumps over a broken down airplane .
# 假设： A person is training his horse for a competition .
# 标签： 2
# 前提： A person on a horse jumps over a broken down airplane .
# 假设： A person is at a diner , ordering an omelette .
# 标签： 1
# 前提： A person on a horse jumps over a broken down airplane .
# 假设： A person is outdoors , on a horse .
# 标签： 0

# %%
test_data = read_snli(data_dir, is_train=False)
for data in [train_data, test_data]:
    print([[row for row in data[2]].count(i) for i in range(3)])

class SNLIDataset(torch.utils.data.Dataset):
    """用于加载SNLI数据集的自定义数据集"""
    def __init__(self, dataset, num_steps, vocab=None):
        self.num_steps = num_steps
        all_premise_tokens = d2l.tokenize(dataset[0])
        all_hypothesis_tokens = d2l.tokenize(dataset[1])
        if vocab is None:
            self.vocab = d2l.Vocab(all_premise_tokens + all_hypothesis_tokens, min_freq=5, reserved_tokens=['<pad>'])
        else:
            self.vocab = vocab
        self.premises = self._pad(all_premise_tokens)
        self.hypotheses = self._pad(all_hypothesis_tokens)
        self.labels = torch.tensor(dataset[2])
        print('read ' + str(len(self.premises)) + ' examples')
        
    def _pad(self, lines):
        return torch.tensor([d2l.truncate_pad(self.vocab[line], self.num_steps, self.vocab['<pad>']) for line in lines])
    
    def __getitem__(self, idx):
        return (self.premises[idx], self.hypotheses[idx]), self.labels[idx]
    
    def __len__(self):
        return len(self.premises)

def load_data_snli(batch_size, num_steps=50):
    """下载SNLI数据集并返回数据迭代器和词表"""
    num_workers = 0
    data_dir = 'D:/data/snli_1.0/snli_1.0'
    train_data = read_snli(data_dir, True)
    test_data = read_snli(data_dir, False)
    train_set = SNLIDataset(train_data, num_steps)
    test_set = SNLIDataset(test_data, num_steps, train_set.vocab)
    train_iter = torch.utils.data.DataLoader(train_set, batch_size,shuffle=True,num_workers=num_workers)
    test_iter = torch.utils.data.DataLoader(test_set, batch_size,shuffle=False,num_workers=num_workers)
    return train_iter, test_iter, train_set.vocab

train_iter, test_iter, vocab = load_data_snli(128, 50)
len(vocab)
# Out:
# [183416, 183187, 182764]
# [3368, 3237, 3219]
# read 9824 examples
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 42
#      39     test_iter = torch.utils.data.DataLoader(test_set, batch_size,shuffle=False,num_workers=num_workers)
#      40     return train_iter, test_iter, train_set.vocab
# ---> 42 train_iter, test_iter, vocab = load_data_snli(128, 50)
#      43 len(vocab)
#
# Cell In[9], line 38, in load_data_snli(batch_size, num_steps)
#      36 train_set = SNLIDataset(train_data, num_steps)
#      37 test_set = SNLIDataset(test_data, num_steps, train_set.vocab)
# ---> 38 train_iter = torch.utils.data.DataLoader(train_set, batch_size,shuffle=True,num_workers=num_workers)
#      39 test_iter = torch.utils.data.DataLoader(test_set, batch_size,shuffle=False,num_workers=num_workers)
#      40 return train_iter, test_iter, train_set.vocab
#
# File c:\Users\gzjcm\anaconda3\envs\dpl\lib\site-packages\torch\utils\data\dataloader.py:385, in DataLoader.__init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device, in_order)
#     383 else:  # map-style
#     384     if shuffle:
# --> 385         sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     386     else:
#     387         sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# File c:\Users\gzjcm\anaconda3\envs\dpl\lib\site-packages\torch\utils\data\sampler.py:155, in RandomSampler.__init__(self, data_source, replacement, num_samples, generator)
#     150 if not isinstance(self.replacement, bool):
#     151     raise TypeError(
#     152         f"replacement should be a boolean value, but got replacement={self.replacement}"
#     153     )
# --> 155 if not isinstance(self.num_samples, int) or self.num_samples <= 0:
#     156     raise ValueError(
#     157         f"num_samples should be a positive integer value, but got num_samples={self.num_samples}"
#     158     )
#
# File c:\Users\gzjcm\anaconda3\envs\dpl\lib\site-packages\torch\utils\data\sampler.py:164, in RandomSampler.num_samples(self)
#     160 @property
#     161 def num_samples(self) -> int:
#     162     # dataset size might change at runtime
#     163     if self._num_samples is None:
# --> 164         return len(self.data_source)
#     165     return self._num_samples
#
# Cell In[9], line 28, in SNLIDataset.__len__(self)
#      27 def __len__(self):
# ---> 28     return len(self.premises)
#
# AttributeError: 'SNLIDataset' object has no attribute 'premises'

# %%
for X, Y in train_iter:
    print(X[0].shape)
    print(X[1].shape)
    print(Y.shape)
    break
